# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""

# your code here
apples = 60
oranges = 40
universe = apples + oranges

p = apples/universe
q = 1 - p

print('The probability of picking an apple is {:.02%}, and picking an orange would yield a probability of {:.02%}'.format(p,q))
# Out:
# The probability of picking an apple is 60.00%, and picking an orange would yield a probability of 40.00%

# %%
from scipy.stats import bernoulli
import seaborn as sns
import numpy as np

data_bern = bernoulli.rvs(size=100,p=0.6)
ax= sns.distplot(data_bern,
                 kde=False,
                 color="lightblue",
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Bernoulli Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Bernoulli Distribution')]

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# your code here
prob_1 = p**5
print('The probability that the first 5 fruits are all apples (with replacement) is {:.02%}'.format(prob_1))

prob_2 = (p**5)*(q**15)
print('The probability that the first 5 fruits are all apples and the next 15 fruits are all oranges (with replacement) is {:.08%}'.format(prob_2))
# Out:
# The probability that the first 5 fruits are all apples (with replacement) is 7.78%
# The probability that the first 5 fruits are all apples and the next 15 fruits are all oranges (with replacement) is 0.00000835%

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
# your code here
from scipy.stats import binom
oranges_pick = 15
n = 20
prob_3 = binom.pmf(oranges_pick, n, q)
print('The probability that this time the sample contains 5 apples and 15 oranges (without order) is {:.02%}.'.format(prob_3))
# Out:
# The probability that this time the sample contains 5 apples and 15 oranges (without order) is 0.13%.

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
# your code here
apples_pick = 4
n = 20
prob_4 = binom.cdf(apples_pick, n, p)
print('The probability that less than 5 fruits picked are apples is {:.05%}.'.format(prob_4))
# Out:
# The probability that less than 5 fruits picked are apples is 0.03170%.

# %% [markdown]
# **Plot the PDF (probability distributiom function) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
# your code here
# Please label the axes and give a title to the plot 

binomial = np.random.binomial(apples_pick, p, size=n)
ax = sns.distplot(binomial)

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
# your code here 
import math

goals_mean = 2.3

poisson = ((goals_mean**5)*math.exp(-goals_mean))/math.factorial(5)

print('The probability that the number of goals scored in a match is 5, is {:.02%}.'.format(poisson))
# Out:
# The probability that the number of goals scored in a match is 5, is 5.38%.

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
from scipy.stats import poisson
x=np.arange(0,11)
fig, ax=plt.subplots(1,1)
ax.plot(x,poisson.pmf(x,goals_mean),'bo',ms=8)
ax.vlines(x,0,poisson.pmf(x,goals_mean),colors='b',lw=5,alpha=0.5)
ax.set_ylabel('Probabilidad')
ax.set_xlabel('Rango')
# Out:
# Text(0.5, 0, 'Rango')
